# %%
import pandas as pd
import numpy as np

# %%
INPUT = '../../experiments/exp13/run1/cat/tables/tcr_barcode.cleaned.csv'

# %%
OUTPUT = '../../experiments/exp13/run3/cat/tables/tcr_barcode.cleaned.csv'

# %% [markdown]
# # Load

# %%
df = pd.read_csv(INPUT)

# %%
df[['label','label_mhc']]
# Out:
#       label  label_mhc
# 0       1.0        1.0
# 1       1.0        1.0
# 2       1.0        1.0
# 3       1.0        1.0
# 4       1.0        1.0
# ...     ...        ...
# 7120    1.0        1.0
# 7121    1.0        1.0
# 7122    1.0        1.0
# 7123    1.0        1.0
# 7124    1.0        1.0
#
# [7125 rows x 2 columns]

# %%
sum((df.label == 1) & df.label_mhc == 1)
# Out:
# 6073

# %%
sum((df.label == 1))
# Out:
# 6073

# %%
df[df.label == 1].to_csv(OUTPUT, index=False)

# %%
df
# Out:
#                      gem      clonotype  num_clonotype      ct  \
# 0     AAACCTGAGCCCAGCT-1  clonotype1825         1825.0  1825.0
# 1     AAACCTGAGTCAATAG-1  clonotype1136         1136.0  1136.0
# 2     AAACCTGCAATCCGAT-1     clonotype3            3.0     3.0
# 3     AAACCTGCAGCCAGAA-1    clonotype79           79.0    79.0
# 4     AAACCTGCATGCCACG-1    clonotype15           15.0    15.0
# ...                  ...            ...            ...     ...
# 7120  TTTGGTTGTTGAGGTG-1     clonotype5            5.0     5.0
# 7121  TTTGTCAAGAATGTTG-1            NaN            0.0  3579.0
# 7122  TTTGTCAAGCGTGAAC-1            NaN            0.0  6790.0
# 7123  TTTGTCATCACCTCGT-1   clonotype233          233.0   233.0
# 7124  TTTGTCATCACTATTC-1            NaN            0.0     3.0
#
#                 genes_TRA                   genes_TRB  \
# 0     TRAV8-3;TRAJ10;TRAC      TRBV6-5;;TRBJ1-2;TRBC1
# 1      TRAV17;TRAJ38;TRAC       TRBV19;;TRBJ2-7;TRBC2
# ...
