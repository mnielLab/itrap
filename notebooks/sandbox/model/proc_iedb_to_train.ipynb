# %%
import pandas as pd
import numpy as np
import re

# %%
import sys  
sys.path.insert(0, '../../scripts')

from D_plot_specificity_matrix_utils import calc_binding_concordance

# %%
def notnan(x):
    return x == x

# %%
def get_multiplets(df):
    #tmp = df[idx1 & idx2]
    dct = df.groupby(['ct','peptide_HLA']).gem.count() > 1
    idx = df.set_index(['ct','peptide_HLA']).index.map(dct)
    return idx.fillna(False)

# %%
def check_aa(seq):
    regex = re.compile('^[ARNDCEQGHILKMFPSTWYV]+$')
    match = regex.search(seq)
    if match is not None:
        return True
    else:
        return False

# %% [markdown]
# # Input

# %%
EXP10x = '../tmp_files/model_data/exp10_x.csv'
EXP131 = '../tmp_files/model_data/exp13_1.csv'
EXP132 = '../tmp_files/model_data/exp13_2.csv'
EXP091 = '../tmp_files/model_data/exp09.csv'

# %%
DATA = '../tmp_files/formatted/vdjdb.csv'

# %% [markdown]
# # Output

# %%
OUT = '../tmp_files/model_data/vdj_test.csv'

# %% [markdown]
# # Load

# %%
dfs = list()
for f in [EXP10x, EXP131, EXP132, EXP091]:
    dfs.append(pd.read_csv(f, header=None, names=['peptide','mhc','cdr3_a','cdr3_b','label']))
    
tenx = pd.concat(dfs, ignore_index=True)
tenx.drop_duplicates(inplace=True)

# %%
#tenx = pd.read_csv(EXP10x, header=None, names=['peptide','mhc','cdr3_a','cdr3_b','label'])

# %%
pep2mhc = tenx.set_index('peptide').mhc.to_dict()

# %%
df = pd.read_csv(DATA, low_memory=False)

# %% [markdown]
# # Filters

# %%
idx1 = df.peptide.isin(tenx.peptide)

# %%
idx2 = ~df.assay.str.contains('single-cell').fillna(False) # VDJdb specific

# %%
idx3 = df.peptide.apply(lambda x: check_aa(x))
idx4 = df.cdr3_a.apply(lambda x: check_aa(str(x)))
idx5 = df.cdr3_b.apply(lambda x: check_aa(str(x)))

# %%
idx6 = (df.cdr3_a.str.len() >= 8) & (df.cdr3_a.str.len() <= 19)
idx7 = (df.cdr3_b.str.len() >= 8) & (df.cdr3_b.str.len() <= 19)

# %%
#idx8 = df.cell_species == 'Homo sapiens' # IEDB
idx8 = df.cell_species == 'HomoSapiens' # VDJdb

# %%
idx9 = ~(df.cdr3_a.isin(tenx.cdr3_a) & df.cdr3_b.isin(tenx.cdr3_b))

# %%
idx10 = ~(df.cdr3_a.isin(tenx.cdr3_a.str[1:-1]) & df.cdr3_b.isin(tenx.cdr3_b.str[1:-1]))

# %% [markdown]
# # Main

# %%
#sub_df = df[idx1 & idx3 & idx4 & idx5 & idx6 & idx7 & idx8 & idx9 & idx10].copy() # IEDB
sub_df = df[idx1 & idx2 & idx3 & idx4 & idx5 & idx6 & idx7 & idx8 & idx9 & idx10].copy() # VDJdb

# %%
sub_df.cdr3_a = sub_df.cdr3_a.apply(lambda x: f'C{x}F' if (x[0]!='C') & ((x[-1]!='F') | (x[-1]!='W')) else x)
sub_df.cdr3_b = sub_df.cdr3_b.apply(lambda x: f'C{x}F' if (x[0]!='C') & ((x[-1]!='F') | (x[-1]!='W')) else x)

# %%
sub_df.dropna(subset=['cdr3_a','cdr3_b'], inplace=True)
sub_df.drop_duplicates(subset=['peptide','cdr3_a','cdr3_b'], inplace=True)

# %%
sub_df
# Out:
#                v_a        j_a  cdr1_a  cdr2_a            cdr3_a          v_b  \
# 667    TRAV38-1*01  TRAJ48*01     NaN     NaN     CAYTVLGNEKLTF    TRBV28*01
# 668    TRAV12-2*01  TRAJ42*01     NaN     NaN   CAVAGYGGSQGNLIF    TRBV28*01
# 669    TRAV12-2*01  TRAJ48*01     NaN     NaN      CAVSFGNEKLTF    TRBV28*01
# 670    TRAV12-2*01  TRAJ42*01     NaN     NaN   CAVTHYGGSQGNLIF    TRBV28*01
# 671    TRAV12-2*01  TRAJ45*01     NaN     NaN     CAGGGGGADGLTF    TRBV28*01
# ...            ...        ...     ...     ...               ...          ...
# 51098  TRAV12-3*01  TRAJ27*01     NaN     NaN    CAMTGTTNAGKSTF  TRBV12-3*01
# 51099     TRAV3*01  TRAJ31*01     NaN     NaN      CAVRDTNARLMF  TRBV12-3*01
# 51101  TRAV26-2*01  TRAJ43*01     NaN     NaN       CIRDNNNDMRF   TRBV7-6*01
# 51102  TRAV26-2*01  TRAJ43*01     NaN     NaN       CIIDNNNDMRF   TRBV7-6*01
# 52851  TRAV26-2*01  TRAJ52*01     NaN     NaN  CILPLAGGTSYGKLTF  TRBV11-1*01
#
#          d_b         j_b  cdr1_b  cdr2_b  ... antigen_source  \
# 667      NaN  TRBJ2-1*01     NaN     NaN  ...    HomoSapiens
# 668      NaN  TRBJ1-1*01     NaN     NaN  ...    HomoSapiens
# 669      NaN  TRBJ1-5*01     NaN     NaN  ...    HomoSapiens
# 670      NaN  TRBJ2-3*01     NaN     NaN  ...    HomoSapiens
# 671      NaN  TRBJ1-5*01     NaN     NaN  ...    HomoSapiens
# ...      ...         ...     ...     ...  ...            ...
# 51098    NaN  TRBJ1-2*01     NaN     NaN  ...            CMV
# 51099    NaN  TRBJ1-1*01     NaN     NaN  ...            CMV
# 51101  TRBD1  TRBJ1-4*01     NaN     NaN  ...            CMV
# 51102  TRBD1  TRBJ1-4*01     NaN     NaN  ...            CMV
# 52851    NaN  TRBJ2-1*01     NaN     NaN  ...            EBV
#
#       peptide_expression          mhc mhc_expression  \
# 667                  NaN     HLA-A*02            NaN
# 668                  NaN     HLA-A*02            NaN
# 669                  NaN     HLA-A*02            NaN
# 670                  NaN     HLA-A*02            NaN
# 671                  NaN     HLA-A*02            NaN
# ...                  ...          ...            ...
# 51098                NaN  HLA-A*02:01            NaN
# 51099                NaN  HLA-A*02:01            NaN
# 51101                NaN  HLA-A*02:01            NaN
# 51102                NaN  HLA-A*02:01            NaN
# 52851                NaN  HLA-B*08:01            NaN
#
#                                                   ref_id pdb_id  \
# 667                                        PMID:12555663    NaN
# 668                                        PMID:12555663    NaN
# 669                                        PMID:12555663    NaN
# 670                                        PMID:12555663    NaN
# 671                                        PMID:12555663    NaN
# ...                                                  ...    ...
# 51098  https://github.com/antigenomics/vdjdb-db/issue...    NaN
# 51099  https://github.com/antigenomics/vdjdb-db/issue...    NaN
# 51101  https://github.com/antigenomics/vdjdb-db/issue...    NaN
# 51102  https://github.com/antigenomics/vdjdb-db/issue...    NaN
# 52851                                       PMID:9862375    NaN
#
#                                       assay database  db_id_tcr db_id_pep
# 667    cultured-T-cells,beads,tetramer-sort    VDJdb        NaN       NaN
# 668    cultured-T-cells,beads,tetramer-sort    VDJdb        NaN       NaN
# 669    cultured-T-cells,beads,tetramer-sort    VDJdb        NaN       NaN
# 670    cultured-T-cells,beads,tetramer-sort    VDJdb        NaN       NaN
# 671    cultured-T-cells,beads,tetramer-sort    VDJdb        NaN       NaN
# ...                                     ...      ...        ...       ...
# 51098                          pelimer-sort    VDJdb        NaN       NaN
# 51099                          pelimer-sort    VDJdb        NaN       NaN
# 51101                          pelimer-sort    VDJdb        NaN       NaN
# 51102                          pelimer-sort    VDJdb        NaN       NaN
# 52851                antigen-loaded-targets    VDJdb          Q       0mo
#
# [377 rows x 27 columns]

# %%
sub_df.mhc = sub_df.peptide.map(pep2mhc)

# %%
sub_df['label'] = 1

# %%
sub_df.peptide.value_counts()
# Out:
# GILGFVFTL     160
# ELAGIGILTV     70
# NLVPMVATV      57
# GLCTLVAML      41
# YVLDHLIVV      11
# AVFDRKSDAK      7
# IVTDFSVIK       7
# TPRVTGGGAM      6
# SLLMWITQV       5
# LLFGYPVYV       3
# FLRGRAYGL       3
# IPSINVHHY       3
# RMFPNAPYL       2
# IMDQVPFSV       1
# RPPIFIRRL       1
# Name: peptide, dtype: int64

# %%
sub_df.peptide.value_counts()
# Out:
# GILGFVFTL     481
# NLVPMVATV     234
# GLCTLVAML     195
# YVLDHLIVV     126
# ELAGIGILTV     82
# RPPIFIRRL      25
# FLRGRAYGL      21
# LLFGYPVYV      16
# IPSINVHHY      12
# IMDQVPFSV       9
# IVTDFSVIK       8
# TPRVTGGGAM      6
# QYDPVAALF       4
# CLGGLLTMV       3
# RMFPNAPYL       2
# ELRRKMMYM       2
# AVFDRKSDAK      2
# SLLMWITQV       1
# RAKFKQLL        1
# VTEHDTLLY       1
# Name: peptide, dtype: int64

# %%
sub_df[['peptide','mhc','cdr3_a','cdr3_b', 'label']]
# Out:
#           peptide    mhc            cdr3_a            cdr3_b  label
# 667    ELAGIGILTV  A0201     CAYTVLGNEKLTF     CASSFTPYNEQFF      1
# 668    ELAGIGILTV  A0201   CAVAGYGGSQGNLIF    CASSPQGLGTEAFF      1
# 669    ELAGIGILTV  A0201      CAVSFGNEKLTF    CAEGQGFVGQPQHF      1
# 670    ELAGIGILTV  A0201   CAVTHYGGSQGNLIF   CASLRSAVWADTQYF      1
# 671    ELAGIGILTV  A0201     CAGGGGGADGLTF    CASTLTGLGQPQHF      1
# ...           ...    ...               ...               ...    ...
# 51098   NLVPMVATV  A0201    CAMTGTTNAGKSTF      CASTYGSYGYTF      1
# 51099   NLVPMVATV  A0201      CAVRDTNARLMF       CASSVVTEAFF      1
# 51101   NLVPMVATV  A0201       CIRDNNNDMRF  CASSLAPGTTNEKLFF      1
# 51102   NLVPMVATV  A0201       CIIDNNNDMRF  CASSLAPGATNEKLFF      1
# 52851   FLRGRAYGL  B0801  CILPLAGGTSYGKLTF     CASSSGQAYEQYF      1
#
# [377 rows x 5 columns]

# %%
sub_df[['peptide','mhc','cdr3_a','cdr3_b','label']].to_csv(OUT, index=False, header=False)
