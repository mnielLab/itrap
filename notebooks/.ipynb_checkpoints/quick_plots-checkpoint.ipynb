# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
TEST = "quality_trimmed"

# %%
FIG_DIR = "/Volumes/tuba/herpov/tcr-pmhc-sc-project/plots/exp3/cutadapt_annotations/%s/" %TEST

# %% [markdown]
# # Distribution of reads if trimmed by quality and length

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
title = "Quality trimming reads (4,886,477 reads)"
labels = 'Passed quality trimming', 'Too short after quality trimming', 'Too long after quality trimming'
sizes = [3035311,1564667,286499]
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title(title)

plt.savefig(FIG_DIR + "_".join(title.split()) + ".png") 
plt.show()

# %% [markdown]
# # Distribution of reads annotated with building blocks

# %%
FILE = "/Volumes/tuba/herpov/tcr-pmhc-sc-project/data/exp3_MHC/cutadapt_naming/%s/headers/annotated_headers.uniq_count.lst" %TEST

# %%
head_df = pd.read_csv(FILE, sep=" ", names=("counts", "tso", "b_primer", "anneal", "cd8_primer", "mhc_primer"))

# %%
head_df.head()
# Out:
#    counts         tso    b_primer      anneal  cd8_primer  mhc_primer
# 0     703  no_adapter  no_adapter      ANNEAL  no_adapter  no_adapter
# 1     745  no_adapter  no_adapter      ANNEAL  no_adapter  PRIMER_MHC
# 2      77  no_adapter  no_adapter      ANNEAL  PRIMER_CD8  no_adapter
# 3       7  no_adapter  no_adapter      ANNEAL  PRIMER_CD8  PRIMER_MHC
# 4   38466  no_adapter  no_adapter  no_adapter  no_adapter  no_adapter

# %%
head_df['a_primer'] = np.where(head_df.cd8_primer == 'no_adapter', head_df.mhc_primer, head_df.cd8_primer)
head_df.replace('no_adapter', np.NaN, inplace=True)
head_df.a_primer = head_df.a_primer.str.slice_replace(start=7, repl='A')
head_df['match'] = head_df.loc[:, ['tso', 'b_primer', 'anneal', 'a_primer']].count(axis=1)

# %%
head_df.replace(np.NaN, '', inplace=True)
head_df['name'] = head_df.tso + " " + head_df.b_primer + " " + head_df.anneal + " " + head_df.a_primer
head_df.loc[head_df.match == 0, 'name'] = "no adapter"

# %%
head_df
# Out:
#      counts  tso  b_primer  anneal  cd8_primer  mhc_primer  a_primer  match  \
# 0       703                 ANNEAL                                        1
# 1       745                 ANNEAL              PRIMER_MHC  PRIMER_A      2
# 2        77                 ANNEAL  PRIMER_CD8              PRIMER_A      2
# 3         7                 ANNEAL  PRIMER_CD8  PRIMER_MHC  PRIMER_A      2
# 4     38466                                                               0
# 5     12187                                     PRIMER_MHC  PRIMER_A      1
# 6      2742                         PRIMER_CD8              PRIMER_A      1
# 7       106                         PRIMER_CD8  PRIMER_MHC  PRIMER_A      1
# 8        33       PRIMER_B  ANNEAL                                        2
# 9       990       PRIMER_B  ANNEAL              PRIMER_MHC  PRIMER_A      3
# 10       96       PRIMER_B  ANNEAL  PRIMER_CD8              PRIMER_A      3
# 11      631       PRIMER_B                                                1
# 12       94       PRIMER_B                      PRIMER_MHC  PRIMER_A      2
# 13       64       PRIMER_B          PRIMER_CD8              PRIMER_A      2
# 14     4541  TSO            ANNEAL                                        2
# 15    59433  TSO            ANNEAL              PRIMER_MHC  PRIMER_A      3
# 16     8931  TSO            ANNEAL  PRIMER_CD8              PRIMER_A      3
# 17      409  TSO            ANNEAL  PRIMER_CD8  PRIMER_MHC  PRIMER_A      3
# 18  1936043  TSO                                                          1
# 19   667358  TSO                                PRIMER_MHC  PRIMER_A      2
# 20   147787  TSO                    PRIMER_CD8              PRIMER_A      2
# 21     7450  TSO                    PRIMER_CD8  PRIMER_MHC  PRIMER_A      2
# 22    18709  TSO  PRIMER_B  ANNEAL                                        3
# 23   108575  TSO  PRIMER_B  ANNEAL              PRIMER_MHC  PRIMER_A      4
# 24    16512  TSO  PRIMER_B  ANNEAL  PRIMER_CD8              PRIMER_A      4
# 25      538  TSO  PRIMER_B  ANNEAL  PRIMER_CD8  PRIMER_MHC  PRIMER_A      4
# 26      418  TSO  PRIMER_B                                                2
# 27     1522  TSO  PRIMER_B                      PRIMER_MHC  PRIMER_A      3
# 28      135  TSO  PRIMER_B          PRIMER_CD8              PRIMER_A      3
# 29        9  TSO  PRIMER_B          PRIMER_CD8  PRIMER_MHC  PRIMER_A      3
#
#                             name
# 0                        ANNEAL
# 1                ANNEAL PRIMER_A
# 2                ANNEAL PRIMER_A
# 3                ANNEAL PRIMER_A
# 4                     no adapter
# 5                       PRIMER_A
# 6                       PRIMER_A
# 7                       PRIMER_A
# 8               PRIMER_B ANNEAL
# 9       PRIMER_B ANNEAL PRIMER_A
# 10      PRIMER_B ANNEAL PRIMER_A
# 11                    PRIMER_B
# 12            PRIMER_B  PRIMER_A
# 13            PRIMER_B  PRIMER_A
# 14                  TSO  ANNEAL
# 15          TSO  ANNEAL PRIMER_A
# 16          TSO  ANNEAL PRIMER_A
# 17          TSO  ANNEAL PRIMER_A
# 18                        TSO
# 19                TSO   PRIMER_A
# 20                TSO   PRIMER_A
# 21                TSO   PRIMER_A
# 22          TSO PRIMER_B ANNEAL
# 23  TSO PRIMER_B ANNEAL PRIMER_A
# 24  TSO PRIMER_B ANNEAL PRIMER_A
# 25  TSO PRIMER_B ANNEAL PRIMER_A
# 26                TSO PRIMER_B
# 27        TSO PRIMER_B  PRIMER_A
# 28        TSO PRIMER_B  PRIMER_A
# 29        TSO PRIMER_B  PRIMER_A

# %%
title = "Number of construct annotations in reads (4,886,477 reads)"
total_sizes = list()
for i in range(5):
    total_sizes.append(head_df[head_df.match == i].counts.sum())
    
labels = list(range(5))

fig1, ax1 = plt.subplots()
wedges, text = ax1.pie(total_sizes, shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title(title)

ax1.legend(wedges, labels,
          title="Building blocks",
          loc="center left",
          bbox_to_anchor=(0.8, 0, 0.5, 1))

plt.savefig(FIG_DIR + "_".join(title.split()) + ".png", bbox_inches='tight') 
plt.show()

# %%
(sum(sizes)/float(4886477))
# Out:
# 1.0

# %%
for i in range(1,4):
    title = "Distribution of constructs (when %i present)" %i
    sizes = head_df[head_df.match == i].groupby('name')['counts'].sum().to_list()
    labels = [" ".join(j.strip().split()) for j in head_df[head_df.match == i].groupby('name')['counts'].sum().index]
    fig1, ax1 = plt.subplots()
    wedges, text = ax1.pie(sizes, shadow=False, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.title(title)

    ax1.legend(wedges, labels,
              title="Building blocks",
              loc="center left",
              bbox_to_anchor=(0.8, 0, 0.5, 1))

    plt.savefig(FIG_DIR + "_".join(title.split()) + ".png", bbox_inches='tight') 
    plt.show()
