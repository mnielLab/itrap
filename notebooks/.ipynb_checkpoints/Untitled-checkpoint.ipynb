# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(np.linspace(-np.pi, np.pi))
y = np.sin(x)*np.pi

plt.subplot(3, 1, 1)
plt.plot(x, y)

plt.subplot(3, 1, 2)
plt.plot(x, y)
plt.axis('scaled')

ax1 = plt.subplot(3, 1, 3)
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.axis('scaled')
# Out:
# (-3.4557519189487724,
#  3.4557519189487724,
#  -3.453976409598375,
#  3.453976409598375)

# %%
plt.plot(x, y)
plt.axis('equal')
# Out:
# (-3.4557519189487724,
#  3.4557519189487724,
#  -3.453976409598375,
#  3.453976409598375)

# %%
plt.plot([(1,87),(2,80)],[(1,88),(0,0)], 'o-')

# %%
import matplotlib.patches as patches
import matplotlib.patheffects as PathEffects



title = "Alignment positions"

# Set up the axes with gridspec
fig = plt.figure(figsize=(14, 6))
grid = plt.GridSpec(2, 1, hspace=0.25, height_ratios=[10,1])

main_ax = plt.subplot(grid[0, 0])
main = plt.plot([(1,87),(2,80)],[(1,88),(0,0)], 'o-')
main = plt.xlim(-3,149) # Variable!
main = plt.xlabel("Alignment positions in template")
main = plt.ylabel("Alignment positions in query")
main = plt.title(title)

subs_ax = plt.subplot(grid[1, 0], yticklabels=[], sharex=main_ax)

cc = plt.rcParams['axes.prop_cycle'].by_key()['color']
bbb = {'TSO':(0, 13, cc[0]), 
       'Primer_B':(13, 19, cc[1]),
       'N6':(32, 6, cc[2]),
       'Oligo_B':(38, 25, cc[3]),
       'Anneal':(63, 25, cc[4]),
       'Oligo_A':(88, 25, cc[5]),
       'N6-':(113, 6, cc[2]),
       'Primer_A':(119, 18, cc[7]),
       'ID':(137, 8, cc[8])} # Variable

for k, v in bbb.items():
    print(k,v)

    # Create a Rectangle patch
    rect = patches.Rectangle((v[0],0),v[1],1, fill=True, color=v[2]) #linewidth=1,edgecolor='r',facecolor='none'
    subs_ax.add_patch(rect)
    
    # Add text
    block = " ".join(k.split("_")).split("-")[0]
    txt = subs_ax.text(v[1]/2.0+v[0], 0.5, block, horizontalalignment='center', verticalalignment='center', color='white',
                       size=15, weight='heavy')
    txt.set_path_effects([PathEffects.withStroke(linewidth=0.5, foreground='black')])
    



plt.show()
# Out:
# TSO (0, 13, '#1f77b4')
# Primer_B (13, 19, '#ff7f0e')
# N6 (32, 6, '#2ca02c')
# Oligo_B (38, 25, '#d62728')
# Anneal (63, 25, '#9467bd')
# Oligo_A (88, 25, '#8c564b')
# N6- (113, 6, '#2ca02c')
# Primer_A (119, 18, '#7f7f7f')
# ID (137, 8, '#bcbd22')

# %%
print(plt.rcParams['axes.prop_cycle'].by_key()['color'])
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
import matplotlib.patches as patches
import matplotlib.patheffects as PathEffects

# Set up the axes with gridspec
fig = plt.figure(figsize=(10, 6))
grid = plt.GridSpec(2, 1, hspace=0.15, height_ratios=[6,1])

main_ax = fig.add_subplot(grid[0, 0])



# scatter points on the main axes
main_ax.plot([(1,87),(2,80)],[(1,88),(0,0)], 'o-')
main_ax.set_xlim=([0,150])

subs_ax = fig.add_subplot(grid[1, 0], yticklabels=[], sharex=main_ax)

# histogram on the attached axes
#subs_ax.vline(y=2)

#bbb = {'TSO':(0, 13, 'black'), 
#       'Primer_B':(13, 32, 'red'),
#       'N1':(32, 38, 'yellow'),
#       'Oligo_B':(38, 63, 'magenta'),
#       'Anneal':(63, 88, 'blue'),
#       'Oligo_A':(88, 113, 'purple'),
#       'N2':(113, 119, 'yellow'),
#       'Primer_A':(119, 137, 'pink'),
#       'Sample':(137, 150, 'green')}
#
#for k, v in bbb.items():
#    print(k,v)
#
#    # Create a Rectangle patch
#    rect = patches.Rectangle((v[0],0),v[1],1, fill=True, color=v[2]) #linewidth=1,edgecolor='r',facecolor='none'
#
#    # Add the patch to the Axes
#    subs_ax.add_patch(rect)
#    #txt = subs_ax.text((v[1]-v[0])/2.0+v[0], 0.5, k, horizontalalignment='center', verticalalignment='center', color='white',
#    #               size=15, weight='heavy')
#    #txt.set_path_effects([PathEffects.withStroke(linewidth=1, foreground='black')])
#    


plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Passed quality trimming', 'Too short after quality trimming', 'Too long after quality trimming'
sizes = [3035311,1564667,286499]
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Distribution of reads from Andreas pipeline (4,886,477 reads)")
plt.show()
